# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px

# %%
# Load the San Francisco AirBNB modified dataset includng current 2021 data

file_path = "./resources/netflix_titles.csv"
nft_df = pd.read_csv(file_path,index_col=0)
nft_df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating   duration  \
# show_id
# s1       25-Sep-21          2020  PG-13     90 min
# ...

# %%
len(nft_df)
# Out:
# 8807

# %%
nft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
nft_df.nunique()
# Out:
# type               2
# title           8804
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# Null Values
nft_df.isnull().values.any()
# Out:
# True

# %%
nft_df.isnull().sum().sum()
# Out:
# 4307

# %%
nft_df['director'].fillna('No Director', inplace=True)
nft_df['cast'].fillna('No Cast', inplace=True)
nft_df['country'].fillna('Country Unavailable', inplace=True)
nft_df.dropna(subset=['date_added','rating'],inplace=True)

# %%
nft_df.isnull().any()
# Out:
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
netflix_titles_df=nft_df.dropna()

# %%
print(netflix_titles_df)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water      No Director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans      No Director
# s5       TV Show           Kota Factory      No Director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb      No Director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast  \
# show_id
# s1                                                 No Cast
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
netflix_movies_df = netflix_titles_df[netflix_titles_df['type']=='Movie'].copy()
netflix_movies_df.head()
# Out:
#           type                             title  \
# show_id
# s1       Movie              Dick Johnson Is Dead
# s7       Movie  My Little Pony: A New Generation
# s8       Movie                           Sankofa
# s10      Movie                      The Starling
# s13      Movie                      Je Suis Karl
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s10                     Theodore Melfi
# s13                Christian Schwochow
#
#                                                       cast  \
# show_id
# s1                                                 No Cast
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
# ...

# %%
netflix_shows_df = netflix_titles_df[netflix_titles_df['type']=='TV Show'].copy()
netflix_shows_df.head()
# Out:
#             type                  title         director  \
# show_id
# s2       TV Show          Blood & Water      No Director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans      No Director
# s5       TV Show           Kota Factory      No Director
# s6       TV Show          Midnight Mass    Mike Flanagan
#
#                                                       cast  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                 No Cast
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
#
#                      country date_added  release_year rating   duration  \
# show_id
# s2              South Africa  24-Sep-21          2021  TV-MA  2 Seasons
# s3       Country Unavailable  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
# Data Preparation

# %%
netflix_movies_df.duration = netflix_movies_df.duration.str.replace(' min','').astype(int)
netflix_shows_df.rename(columns={'duration':'seasons'}, inplace=True)
netflix_shows_df.replace({'seasons':{'1 Season':'1 Seasons'}}, inplace=True)
netflix_shows_df.seasons = netflix_shows_df.seasons.str.replace(' Seasons','').astype(int)

# %%
# Exploratory Analysis and Visualization

# %%
netflix_titles_df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water      No Director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans      No Director
# s5       TV Show           Kota Factory      No Director
#
#                                                       cast  \
# show_id
# s1                                                 No Cast
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                 No Cast
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#
#                      country date_added  release_year rating   duration  \
# show_id
# s1             United States  25-Sep-21          2020  PG-13     90 min
# s2              South Africa  24-Sep-21          2021  TV-MA  2 Seasons
# ...

# %%
# Netflix Film Types: Movie or TV Show

# %%
plt.figure(figsize=(8,6))
g = sns.countplot(netflix_titles_df.type, palette="pastel");
plt.title("Count of Movies and TV Shows")
plt.xlabel("Type (Movie/TV Show)")
plt.ylabel("Total Count")
plt.show()
# Out:
# C:\anaconda\envs\PythonData\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,6))
plt.title("% of Netflix Titles that are either Movies or TV Shows")
g = plt.pie(netflix_titles_df.type.value_counts(), explode=(0.025,0.025), labels=netflix_titles_df.type.value_counts().index, colors=['skyblue','navajowhite'],autopct='%1.1f%%', startangle=180);
plt.legend()
plt.show()

# %%
# Netflix Film Ratings

# %%
order =  ['G', 'TV-Y', 'TV-G', 'PG', 'TV-Y7', 'TV-Y7-FV', 'TV-PG', 'PG-13', 'TV-14', 'R', 'NC-17', 'TV-MA']
plt.figure(figsize=(15,7))
g = sns.countplot(netflix_titles_df.rating, hue=netflix_titles_df.type, order=order, palette="pastel");
plt.title("Ratings for Movies & TV Shows")
plt.xlabel("Rating")
plt.ylabel("Total Count")
plt.show()
# Out:
# C:\anaconda\envs\PythonData\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
